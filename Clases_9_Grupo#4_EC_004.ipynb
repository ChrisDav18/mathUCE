# %% [markdown]
# <a href="https://colab.research.google.com/github/ChrisDav18/mathUCE/blob/main/Clases_9_Grupo%234_EC_004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # $$ \text{👨‍👩‍👧‍👦 Grupo 4 | CLASE 9 📒} $$

# %% [markdown]
# - **Francis Rocha:** *Coordinador y Editor general del Notebook*
# - **Lisbeth Cuji - Patrick Altamirano:** *Parte 1*
# - **Mario Manosalvas - Dilan Jácome:** *Parte 2*
# - **Katty Torres - Leonardo Arciniega:** *Preguntas*

# %% [markdown]
# # $$ \text{🏹 Primera Parte | TEMAS 📚} $$

# %% [markdown]
# ## **📝 Continuidad local y global**

# %% [markdown]
# #### **Introducción**
#
#
# En el estudio de funciones matemáticas, la continuidad es una propiedad fundamental. La continuidad puede ser estudiada de manera global (en toda la extensión de la función) o de manera local (en puntos específicos).
#
# **⚙ Continuidad de Funciones**
#
# ***📌 Definición:*** Una función es contínua cuando podemos dibujarla con un sólo trazo del lápiz, es decir, sin levantar este del papel.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **🔻Continuidad en un Punto**
# Decimos que una función es continua en x=a cuando:
#
# ![image.png](data:image/png;base64,...)
#
# La condición implica, estas condiciones:
#
# + La función está definida en x=a: ∃*f(a)*
# + Existe el límite, y es finito:
# $$ \exists \lim_{x \to a} f(x) \in \mathbb{R} $$
# Esta condición implica que los límites laterales coinciden por ende:
# $$ \lim_{x \to a^-} f(x) = \lim_{x \to a^+} f(x) $$

# %% [markdown]
# Una función sea continúa en un punto implica que la función está definida en el punto y en un entorno del mismo. Aunque queda fuera del alcance de este nivel, podemos dar una definición formal basándonos en estas dos ideas:
# + Formalmente, decimos que una función*f(x)* es continua en a cuando, para cualquier entorno de *f(a)* que fijemos, se puede encontrar un entorno de a cuyas imágenes correspondientes estén contenidas en el entorno de *f(a)* . Esto implica:
# $$
# 1. \ \exists f(a) \\
# 2. \ \forall \varepsilon > 0, \ \exists \delta > 0 \ | \ \text{si} \ |x - a| < \delta \Rightarrow |f(x) - f(a)| < \varepsilon
# $$

# %% [markdown]
# **✨ Donde:**
#
# **ε:** Es el valor que define el entorno de f(a) en el eje y
#
# **δ:** Es el valor que define el entorno de a en el eje x

# %% [markdown]
# ### **🎲 Continuidad en un Intervalo Abierto**
# Decimos que una función es continua en un intervalo abierto (a,b) cuando es continua en todos los puntos pertenecientes a dicho intervalo.
#
# Las funciones elementales que estudiamos normalmente, definidas por una sola expresión analítica, como por ejemplo:
#
# + $$f(x) = 3x^2 + 3$$
# + $$f(x) = \cos(x)$$
# + $$f(x) = \sqrt{x}$$
#
# Estas tres funciones son continuas en todo su dominio.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **🔎Explicación de la Imagén**
#
# **⭕Continuidad en intervalo abierto (a,b)**
#
# A la izquierda, en 1, la función es continua en todos los puntos del intervalo abierto (a,b). Por ello decimos que es continua en el intervalo. A la derecha, en 2, la función presenta un punto de discontinuidad en x=c, con lo que decimos que la función no es continua en dicho intervalo. Por otro lado, recuerda que para definir la continuidad en un punto es necesario que la función esté definida en un entorno del propio intervalo. Observa, en 1, que cualquier punto de los reales perteneciente a un intervalo abierto tiene un entorno contenido en el propio intervalo, incluso los puntos próximos a los extremos. Así, el punto a+0.01, muy próximo al extremo inferior a tiene un entorno en el propio intervalo (a,b) que nos permite aplicar la definición de continuidad. Si lo piensas, esto ocurre para cualquier valor concreto próximo a los extremos del intervalo.

# %% [markdown]
# ### **⬛ Continuidad en un Intervalo Cerrado**
# Decimos que una función es continua en un intervalo cerrado [a,b] cuando:
#
# + *f(x)* es continua en el intervalo abierto (a,b). Esto cubre todos los puntos del intervalo salvo los extremos.
# + $$\lim_{x \to \ a+ } f(x) = f(a) \quad \text{y} \quad \lim_{x \to \ a-} f(x) = f(b)$$
# Esto contempla la continuidad por la derecha de a y la continuidad por la izquierda de b respectivamente.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **📋 Explicación de la Imagén:**
#
# **💡 Continuidad en intervalo cerrado [a,b]**
#
# A la izquierda, en 1, la función es continua en todos los puntos del intervalo abierto (a,b) contenido en [a,b]. Además, es continua por la derecha de a y por la izquierda de b, con lo que decimos que *f(x)* es continua en [a, b]. A la derecha, aunque la función es también continua en (a,b), sin embargo no lo es por la izquierda de b (pues ∄f(b)), con lo que la función no es continua en [a, b].

# %% [markdown]
# ### Continuidad local 📟
# Una función f es continua en un punto x de su dominio si para todo $ε$ positivo, existe un $δ$ positivo tal que para cualquier otro punto y en el dominio de f que satisfaga $|x - y| < δ$, se cumple $|f(x) - f(y)| < ε$.
#
# En otras palabras, para valores de entrada cercanos a x, los valores de salida de f también son cercanos. La continuidad local se puede visualizar como la capacidad de "hacer zoom" en un punto sin observar cambios abruptos en el comportamiento de la función.
#
# Por tanto, una función $f$ es continua en un punto $x = c$  si se cumplen las siguientes condiciones:
#
# 1. $f(c)$ está definida (existe).
# 2. El límite de $f(x)$ cuando $x$ tiende a $c$ existe.
# 3. El límite de $f(x)$ cuando $x$ tiende a $c$ es igual a $f(c)$.
#
# Formalmente, podemos expresar esto como:
#
# $$ \lim_{x \to c} f(x) = f(c) $$
#
#
# ### **Ejemplo 1**
#
# Consideremos la función $f(x) = x^2$. Queremos verificar si es continua en $x = 2$.
#
# *Proceso:*
#
# $f(2) = 2^2 = 4$$f(2) = 2^2 = 4$. (La función está definida en $x = 2$).
#
# $\lim_{x \to 2} f(x) = \lim_{x \to 2} x^2 = 4$ (El límite existe).
#
# Por lo tanto el $\lim_{x \to 2} f(x) = f(2)$, indica que la función es continua en $x = 2$.
#
# **Gráfico**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 4, 400)
y = x**2

plt.plot(x, y, label='$f(x) = x^2$')
plt.scatter([2], [4], color='red')  # Punto de interés (2,4)
plt.axvline(x=2, color='gray', linestyle='--')
plt.axhline(y=4, color='gray', linestyle='--')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfico de $f(x) = x^2$ en $x = 2$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Nota: Es continua en $x=2$

# %% [markdown]
# #### **Ejemplo 2**
#
# Consideremos la función $g(x) = \frac{1}{x}$$g(x) = \frac{1}{x}$. Queremos verificar si es continua en $x = 0$.
#
# $g(0)$ no está definida, ya que la división por cero no está permitida.
#
# Por lo tanto, no podemos evaluar el límite ni comprobar la igualdad.
#
# Concluimos que $g(x)$ no es continua en $x = 0$.

# %%
x = np.linspace(-4, 4, 400)
y = 1 / x

plt.plot(x, y, label='$g(x) = \dfrac{1}{x}$')
plt.axvline(x=0, color='gray', linestyle='--')
plt.ylim(-10, 10)
plt.xlabel('x')
plt.ylabel('g(x)')
plt.title('Gráfico de $g(x) = \dfrac{1}{x}$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Nota: Como se puede observa, la función no esta definida y por lo tanto no es continua.

# %% [markdown]
# ### Continuidad Global 🌎
#
# Una función es continua en un intervalo si es continua en cada punto de ese intervalo. Si una función es continua en toda la recta real, decimos que es continua globalmente.
#
# Naturalmente, decimos que una función $f : E → F$  es continua en un conjunto no vacío $A ⊂ E$ cuando es continua en todo punto $x ∈ A$. Si $f$ es continua en $E$ decimos simplemente que $f$ es continua.
#
# **Para cualquier función $f : E → F$ las siguientes afirmaciones son equivalentes:**
#
#
# - (i) f es continua.
# - (ii) Para todo abierto $V ⊂ F$ , se tiene que $f^{-1}$ (V) es un abierto de $E$.
# - (iii) Para todo cerrado $C ⊂ F$, se tiene que $f^{-1}$ (C) es un cerrado de $E$.
# - (iv) f preserva la convergencia de sucesiones: para toda sucesión convergente ${x_n}$ de puntos de E, la sucesión ${ f(x_n)}$ es convergente.
#
# Las caracterizaciones de la continuidad, dadas por las condiciones (ii) y (iii) del último
# resultado, se usan a menudo para probar que ciertos subconjuntos de E son abiertos o cerrados.
#
# Por ejemplo, tomando $F$ = $\mathbb{R}$ observamos que si $f : E → R$ es una función continua, entonces los conjuntos:
#
# - ${x ∈ E : f(x) > 0}$ = $f^{-1}$ ($\mathbb{R}^+$)
# - ${x ∈ E : f(x) < 0}$ = $f^{-1}$ ($\mathbb{R}^+$)
#
# Por lo tanto, son abiertos, mientras que el conjunto ${x ∈ E : 0 ≤ f(x) ≤ 1}$ = $f^{-1}$ $([0,1])$ es cerrado.
#
# Por otro lado, resaltamos que la continuidad de f , no sólo en un punto, sino en todo el espacio E , tiene **carácter local**, en el sentido de que se puede comprobar con sólo conocer f localmente: f es continua si, y sólo si, para cada  $x ∈ E$ existe $U ∈ U(x)$ tal que $f |_U$ es continua.

# %%
def H(x):
  if x < 0:
    return 0
  else:
    return 1

# %% [markdown]
# Nota: La función $H(x)$ es continua en todos los puntos excepto en $x = 0$. En este punto, la función experimenta un salto abrupto de 0 a 1. Por lo tanto, la función es continua localmente en todos los puntos excepto en x = 0, pero no es continua globalmente.

# %%
import matplotlib.pyplot as plt
import numpy as np

def H(x):
  return np.where(x < 0, 0, 1)  # Usamos np.where para aplicar la función a cada elemento

x = np.arange(-2, 2, 0.1)
y = H(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('H(x)')
plt.title('Función escalón de Heaviside')
plt.grid(True)
plt.show()

# %% [markdown]
# Nota: La imagen muestra una gráfica que indica la función escalón de Heaviside, H(x), con énfasis en la discontinuidad en $x = 0$.

# %% [markdown]
# #### **Ejemplo 3**
#
# La función $h(x) = x^3$$h(x) = x^3$ es continua en todos los puntos de la recta real. Por lo tanto, es continua globalmente.
#
# 1. $h(c) = c^3$ está definida para cualquier $c \in \mathbb{R}$$c \in \mathbb{R}$.
# 2. El límite $\lim_{x \to c} h(x) = \lim_{x \to c} x^3 = c^3$ existe para cualquier $c \in \mathbb{R}$$c \in \mathbb{R}$.
# 3. Como el limite $\lim_{x \to c} h(x) = h(c)$ es para cualquier $c \in \mathbb{R}$, la función es continua en todos los puntos de la recta real.
#
# ### **Ejemplo 4**
#
# Consideremos la función $k(x)$ definida por:
#
# $$ k(x) = \begin{cases} x^2 & \text{si } x \leq 1 \\ 2x - 1 & \text{si } x > 1 \end{cases} $$
#
# Queremos verificar la continuidad global de $k(x)$.
#
# 1. $k(x)$ es continua en $x \neq 1$ ya que ambas piezas de la función ($x^2$ y  $2x - 1$) son continuas en sus dominios respectivos.
#
# Nota: (Es necesario analizar la continuidad en el punto de unión de las dos piezas, es decir, en x = 1, para determinar si la función es continua globalmente).
#
# 2. Verificamos la continuidad en $x = 1$:
# - $\lim_{x \to 1^-} k(x) = \lim_{x \to 1^-} x^2 = 1$
# $\lim_{x \to 1^+} k(x) = \lim_{x \to 1^+} (2x - 1) = 1$
# $k(1) = 1^2 = 1$, dado que el limite:
#  $\lim_{x \to 1^-} k(x) = \lim_{x \to 1^+} k(x) = k(1)$, $k(x)$ es continua en $x = 1$.
#
# Por lo tanto, concluimos que $k(x)$ es continua en toda la recta real.
#
# **Graficos Ejemplos 3 y 4**

# %%
x = np.linspace(-2, 2, 400)
y = x**3

plt.plot(x, y, label='$h(x) = x^3$')
plt.xlabel('x')
plt.ylabel('h(x)')
plt.title('Gráfico de $h(x) = x^3$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Nota: Es continua en toda la recta real.

# %%
x1 = np.linspace(-2, 1, 200)
y1 = x1**2
x2 = np.linspace(1, 4, 200)
y2 = 2*x2 - 1

plt.plot(x1, y1, label='$k(x) = x^2$ cuando $x \leq 1$')
plt.plot(x2, y2, label='$k(x) = 2x - 1$ cuando $x > 1$')
plt.scatter([1], [1], color='red')  # Punto de interés (1,1)
plt.axvline(x=1, color='gray', linestyle='--')
plt.axhline(y=1, color='gray', linestyle='--')
plt.xlabel('x')
plt.ylabel('k(x)')
plt.title('Gráfico de $k(x)$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Nota: Es continua en $x=1$

# %% [markdown]
# ### **🧩 Propiedades:**
# Sean *f(x)* y *g(x)* dos funciones continuas en x=a. Se cumplen las siguientes propiedades:
#
# + La suma de funciones continuas en a es continua en a
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# + El producto de funciones continuas en a es continuo en a
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# + El cociente de funciones continuas en a es continuo en a, siempre que no se anule el denominador
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por otro lado, sea f(x) continua en a y g(x) continua en f(a), entonces la función compuesta (g∘f)(x) es continua en a:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **📍 Consecuencias de estas Propiedades**
# + Las funciones polinómicas son continuas en ℝ
#
# Justificación: La función constante f(x)=k es continua en ℝ. La función identidad f(x)=x también lo es. Un monomio puede ser considerado un producto de funciones identidad con una función constante, que también será continuo en ℝ por estar formado por el producto de varias funciones continuas. Así, por ejemplo f(x)=3·x4=3·x·x·x·x. Finalmente, un polinomio es la suma de varios monomios, y por tanto también será continua en ℝ.
#
# + Las funciones racionales son continuas en su dominio, es decir, en todos los puntos que no anulen el denominador
#
# + Las funciones compuestas son continuas en su dominio

# %% [markdown]
# ### **🖥 Continuidad en Python**

# %%
from scipy.integrate import quad

def f(x):
    # Insert the function expression here
    return x**3 + 1 / x

a = 0  # Lower limit of integration
b = 1  # Upper limit of integration

# Attempt to calculate the integral. If continuous, the integral should converge.
try:
    integral, _ = quad(f, a, b)
    print(f"The integral of f(x) over [a, b] is: {integral}")
    print("f(x) is likely continuous in the interval [a, b]")
except ValueError:
    print("Unable to calculate the integral. f(x) might be discontinuous in the interval [a, b]")
# Out:
# The integral of f(x) over [a, b] is: 41.926840675388085
# f(x) is likely continuous in the interval [a, b]
# <ipython-input-7-1606e6cc1e1d>:12: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   integral, _ = quad(f, a, b)

# %% [markdown]
# ## **📖 Espacios Métricos y Conjuntos Abiertos**

# %% [markdown]
# ### 📐 **Espacios Métricos**
#
# #### *¿Qué es un Espacio Métrico?*
#
# Un **espacio métrico** es una colección de puntos que tiene una forma de medir la distancia entre cada par de puntos. Esta "forma de medir" se llama **métrica**. La métrica es una función que toma dos puntos y devuelve un número que representa la distancia entre ellos.

# %% [markdown]
# #### 🧩**Propiedades de una Métrica**
#
# Para que una función sea una métrica, debe cumplir cuatro propiedades:
#
# 1. **No negatividad**: La distancia entre dos puntos siempre es un número no negativo.
#    - $d(x, y) \geq 0$
#
# 2. **Identidad**: La distancia entre un punto y sí mismo es cero.
#    - $d(x, x) = 0$
#
# 3. **Simetría**: La distancia de un punto $A$ a un punto $B$ es la misma que la distancia de $B$ a $A$.
#    - $d(x, y) = d(y, x)$
#
# 4. **Desigualdad Triangular**: La distancia directa entre dos puntos es siempre menor o igual a la suma de las distancias a través de un tercer punto.
#    - $d(x, y) \leq d(x, z) + d(z, y)$

# %% [markdown]
# #### 🎢**Ejemplos de Espacios Métricos**
#
# 1. **Línea Recta (R)**
#
#    En una línea recta (como una recta numérica), podemos usar la distancia absoluta entre dos puntos.
#    - Métrica: $d(x, y) = |x - y|$
#
#    **Ejemplo:**
#    - Si $x = 2$ y $y = 5$, entonces $d(2, 5) = |2 - 5| = 3$.
#
# 2. **Plano (R²)**
#
#    En un plano (como una hoja de papel), podemos usar la distancia euclidiana entre dos puntos.
#    - Métrica: $d((x_1, y_1), (x_2, y_2)) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$
#
#    **Ejemplo:**
#    - Si $A = (1, 2)$ y $B = (4, 6)$, entonces $d(A, B) = \sqrt{(4 - 1)^2 + (6 - 2)^2} = \sqrt{3^2 + 4^2} = \sqrt{9 + 16} = \sqrt{25} = 5$.
#
# 3. **Espacios de Funciones**
#
#    Podemos definir una métrica entre funciones, por ejemplo, tomando la máxima diferencia entre sus valores.
#    - Métrica: $d(f, g) = \sup_{x \in [a, b]} |f(x) - g(x)|$
#
#    **Ejemplo:**
#    - Si $f(x) = x^2$ y $g(x) = x$ en el intervalo $[0, 1]$, entonces $d(f, g) = \max_{x \in [0, 1]} |x^2 - x|$. Aquí, el máximo se alcanza en $x = 1$, por lo que $d(f, g) = |1^2 - 1| = 0$.

# %% [markdown]
# #### 👀**Visualizando Espacios Métricos**
#
# ### *Línea Recta*
#
# Imaginemos una recta numérica. La distancia entre $x = 2$ y $y = 5$ se puede visualizar así:

# %%
import matplotlib.pyplot as plt

# Coordenadas
x = [2, 3, 4, 5]

# Gráfico
plt.plot(x, [0, 0, 0, 0], 'ro-')
plt.text(2, 0.1, '2', horizontalalignment='center')
plt.text(3, 0.1, '3', horizontalalignment='center')
plt.text(4, 0.1, '4', horizontalalignment='center')
plt.text(5, 0.1, '5', horizontalalignment='center')

plt.ylim(-0.5, 1)
plt.yticks([])
plt.title("Distancia en una Línea Recta")
plt.show()

# %% [markdown]
# **Plano**
#
# Imaginemos un plano con puntos $A = (1, 2)$ y $B = (4, 6)$. La distancia se calcula con el teorema de Pitágoras:

# %%
import matplotlib.pyplot as plt

# Puntos
A = (1, 2)
B = (4, 6)

# Gráfico
plt.plot([A[0], B[0]], [A[1], B[1]], 'ro-')
plt.text(A[0], A[1], 'A (1, 2)', horizontalalignment='right')
plt.text(B[0], B[1], 'B (4, 6)', horizontalalignment='right')

plt.xlim(0, 5)
plt.ylim(0, 7)
plt.grid(True)
plt.title("Distancia en un Plano")
plt.show()

# %% [markdown]
# #### ✍️**Aplicaciones de Espacios Métricos**
#
# - **Convergencia de Secuencias y Series:** Los espacios métricos proporcionan un marco para definir la convergencia de secuencias y series. La noción de límite en un espacio métrico se basa en la idea de que la distancia entre términos de una secuencia y su límite puede ser hecha arbitrariamente pequeña.
#
# - **Estudio de Funciones:** En el análisis, los espacios métricos se utilizan para definir conceptos como continuidad, límites, y derivadas. Las propiedades de las funciones se exploran en términos de la métrica que define las distancias entre puntos en el dominio y en el codominio.
#
# - **Geometría de Espacios Métricos:** La métrica proporciona una manera de medir distancias y ángulos, lo que permite estudiar geometría en espacios métricos. Esto incluye el estudio de conceptos como compacidad, convexidad y propiedades geométricas de los espacios.
#
# - **Geometría de Espacios de Banach y Hilbert:** Los espacios métricos son la base para espacios más especializados como los espacios de Banach y Hilbert, que se utilizan en la geometría funcional para estudiar espacios vectoriales con métricas inducidas por normas y productos internos.
#
# - **Algoritmos de Optimización:** En la optimización, los espacios métricos se utilizan para definir conceptos como cercanía a un óptimo y para desarrollar métodos iterativos como el método del gradiente descendente.
#
# - **Teoremas de Existencia de Óptimos:** Los espacios métricos son el marco para teoremas que garantizan la existencia de puntos óptimos bajo ciertas condiciones, como el teorema de Brouwer para funciones continuas en espacios métricos.
#
# - **Espacios de Probabilidad:** En la teoría de la probabilidad, los espacios métricos se utilizan para definir conceptos como la distancia entre distribuciones de probabilidad y para desarrollar teorías de convergencia de variables aleatorias.
#
# - **Espacios Métricos en Teoría de la Información:** Los espacios métricos se usan en la teoría de la información para definir distancias entre distribuciones de probabilidad y para medir la divergencia entre eventos aleatorios.
#
# - **Métodos de Clustering:** En el análisis de datos, los espacios métricos son fundamentales para algoritmos de clustering como k-medias y análisis de agrupamiento basado en distancias.
#
# - **Reducción de Dimensionalidad:** Los conceptos métricos se utilizan en técnicas de reducción de dimensionalidad, como el Análisis de Componentes Principales (PCA) y técnicas basadas en distancias como el MDS (Multidimensional Scaling).
#
# - **Modelado de Estrategias:** Los espacios métricos se utilizan para modelar estrategias en juegos, donde las distancias pueden representar diferencias en las estrategias de los jugadores y en la evaluación de resultados.
#
# - **Espacios de Características:** En machine learning, los espacios métricos ayudan a definir y analizar espacios de características para algoritmos de aprendizaje supervisado y no supervisado.
#
# - **Optimización de Modelos:** Los espacios métricos son fundamentales para la optimización de modelos de machine learning, incluyendo la minimización de funciones de costo y la evaluación del desempeño de los modelos.
#
# - **Estabilidad de Sistemas Dinámicos:** En teoría de control, los espacios métricos se utilizan para analizar la estabilidad de sistemas dinámicos y para diseñar controladores que aseguren el comportamiento deseado del sistema.

# %% [markdown]
# ### 🧿 **Conjuntos Abiertos**
#
# En matemáticas, especialmente en topología, un **conjunto abierto** es un concepto fundamental. Vamos a explicarlo de una manera simple.
#
# #### *¿Qué es un Conjunto Abierto?*
#
# Un conjunto abierto es un conjunto de puntos que no incluye sus fronteras. Imagina que tienes un círculo dibujado en un papel. Si consideras todos los puntos **dentro** del círculo, pero **no** los puntos que están exactamente en la circunferencia, tienes un conjunto abierto.

# %% [markdown]
# #### 🪔**Ejemplo: Círculo Abierto**
#
# En el gráfico de abajo, tenemos un círculo abierto. La región azul clara dentro del círculo representa todos los puntos que forman parte del conjunto abierto. La línea azul que forma la circunferencia no es parte del conjunto abierto.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definición del intervalo y de los puntos
x = np.linspace(-1, 1, 400)
y = np.sqrt(1 - x**2)

fig, ax = plt.subplots()

# Dibujo del círculo
ax.plot(x, y, color='blue')
ax.plot(x, -y, color='blue')

# Puntos dentro del círculo
theta = np.linspace(0, 2 * np.pi, 100)
r = 0.5
x_inside = r * np.cos(theta)
y_inside = r * np.sin(theta)

ax.fill(x_inside, y_inside, color='lightblue', alpha=0.5)

# Ajustes del gráfico
ax.set_aspect('equal')
ax.axhline(0, color='black',linewidth=0.5)
ax.axvline(0, color='black',linewidth=0.5)
ax.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
ax.set_title("Ejemplo de Conjunto Abierto: Círculo Abierto")

plt.show()

# %% [markdown]
# #### 🧩**Propiedades de los Conjuntos Abiertos**
#
# 1. **Todo punto dentro del conjunto tiene un "espacio alrededor" que también está dentro del conjunto.**
#    - Si tomas cualquier punto dentro del círculo abierto, puedes dibujar un círculo más pequeño alrededor de ese punto que aún se encuentra completamente dentro del círculo grande.
#
# 2. **No incluye los puntos en el borde.**
#    - Si tomas un punto en el borde del círculo (en la circunferencia), no es parte del conjunto abierto.

# %% [markdown]
# #### 🎢**Ejemplo en la Vida Real**
#
# Imagina que tienes un parque circular. Si decimos que el parque es un conjunto abierto, significa que cualquier persona caminando dentro del parque no puede caminar exactamente en la cerca del borde, pero puede moverse libremente en cualquier lugar dentro del parque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definición del círculo grande (el parque)
theta = np.linspace(0, 2 * np.pi, 100)
r = 1
x_park = r * np.cos(theta)
y_park = r * np.sin(theta)

# Definición de los puntos caminando dentro del parque (círculo pequeño)
r_inner = 0.8
theta_inner = np.linspace(0, 2 * np.pi, 100)
x_inner = r_inner * np.cos(theta_inner)
y_inner = r_inner * np.sin(theta_inner)

# Dibujo del parque
fig, ax = plt.subplots()
ax.plot(x_park, y_park, label='Borde del parque', color='blue')
ax.fill(x_inner, y_inner, label='Personas caminando', color='lightblue', alpha=0.5)

# Puntos caminando dentro del parque
for _ in range(10):
    angle = np.random.uniform(0, 2 * np.pi)
    distance = np.random.uniform(0, r_inner)
    x_person = distance * np.cos(angle)
    y_person = distance * np.sin(angle)
    ax.plot(x_person, y_person, 'ro')

# Ajustes del gráfico
ax.set_aspect('equal')
ax.axhline(0, color='black',linewidth=0.5)
ax.axvline(0, color='black',linewidth=0.5)
ax.grid(color='gray', linestyle='--', linewidth=0.5)
ax.set_title("Ejemplo: Parque Circular como Conjunto Abierto")
ax.legend()

plt.show()

# %% [markdown]
# - La línea azul representa el borde del parque (circunferencia del círculo).
#
# - La región azul clara muestra el área donde las personas pueden caminar.
#
# - Los puntos rojos representan personas caminando dentro del parque, pero no exactamente en el borde.

# %% [markdown]
# #### ✍️**Aplicaciones de Conjuntos Abiertos**
#
# Los conjuntos abiertos son un concepto fundamental en matemáticas, especialmente en el análisis matemático y la topología. Aquí tienes algunas aplicaciones de los conjuntos abiertos en diferentes campos:
#
# - **Teoremas de Convergencia:** Los conjuntos abiertos se utilizan en la definición de conceptos como la convergencia de secuencias y series. Por ejemplo, una secuencia converge a un límite si, para cualquier conjunto abierto que contenga el límite, eventualmente todos los términos de la secuencia están dentro de ese conjunto abierto.
# - **Derivadas e Integrales:** La noción de derivada y la teoría de integrales utilizan conjuntos abiertos para definir conceptos como continuidad y diferenciabilidad en intervalos abiertos.
#
# - **Espacios Topológicos:** Los conjuntos abiertos son fundamentales para la definición de espacios topológicos. La estructura de un espacio topológico se basa en una colección de conjuntos abiertos que cumplen ciertos axiomas.
# - **Compactación y Conectividad:** Los conceptos de compactación y conectividad en topología se definen en términos de conjuntos abiertos. Por ejemplo, un conjunto es compacto si cada cubierta abierta tiene una subcubierta finita.
#
# - **Función Continua:** En el análisis real y complejo, una función es continua si la preimagen de cada conjunto abierto es un conjunto abierto. Esto es crucial para el estudio de funciones y sus propiedades.
#
# - **Teoremas de Existencia y Unicidad:** Los conjuntos abiertos se utilizan en los teoremas que garantizan la existencia y unicidad de soluciones para ecuaciones diferenciales. Estos teoremas a menudo requieren que las condiciones se cumplan en un conjunto abierto en el dominio.
#
# - **Métodos de Gradiente:** En la optimización, los métodos de gradiente y otros algoritmos utilizan conceptos relacionados con conjuntos abiertos para definir regiones en las que se busca mejorar una función objetivo.
#
# - **Espacios de Probabilidad:** En la teoría de la probabilidad, los conjuntos abiertos se utilizan en la definición de sigma-álgebras, que son colecciones de conjuntos que permiten definir medidas de probabilidad.
#
# - **Estrategias en Juegos:** En la teoría de juegos, los conjuntos abiertos pueden usarse para modelar las estrategias de los jugadores y analizar equilibrios en juegos de múltiples etapas.
#
# - **Algoritmos de Optimización:** En el campo de machine learning, muchos algoritmos de optimización, como los métodos basados en gradientes, dependen de conceptos matemáticos que incluyen conjuntos abiertos.
#
# - **Estabilidad y Control:** En el control de sistemas, los conceptos de estabilidad y diseño de controladores a menudo se basan en propiedades de conjuntos abiertos en el espacio de estados.

# %% [markdown]
# ### 🧾**Resumen**
#
# Un espacio métrico es un conjunto de puntos con una forma de medir la distancia entre ellos.
# La métrica debe cumplir cuatro propiedades: no negatividad, identidad, simetría y desigualdad triangular.
# Ejemplos de espacios métricos incluyen la recta numérica, el plano y espacios de funciones.
# Los espacios métricos tienen aplicaciones en GPS, inteligencia artificial y análisis de datos.
#
# Un conjunto abierto es como un área sin su borde. Es un conjunto de puntos donde cada punto tiene algo de espacio libre alrededor de él sin salir del conjunto. Este concepto es crucial en muchas áreas de las matemáticas y tiene aplicaciones en análisis, geometría, y más.

# %% [markdown]
# # $$ \text{🏹 Segunda Parte | VIDEO Y MIRO 🎞️} $$

# %% [markdown]
# ## 📽️**Resumen del Video de la Clase 9**
#
# # *Espacios Métricos y Conjuntos Abiertos |  Fundamentos del Análisis*
#
# En el estudio del análisis matemático, los conceptos de espacio métrico y conjunto abierto son fundamentales. Estos conceptos permiten definir y analizar la estructura y propiedades de diferentes tipos de espacios, facilitando el desarrollo de teorías y aplicaciones en diversas áreas de la matemática.

# %% [markdown]
# ### 📐***Espacios Métricos***
#
# #### *Definición de Espacio Métrico*
# Un **espacio métrico** es un par ordenado $ (X, d) $ donde $X$ es un conjunto no vacío y $ d $ es una función denominada **métrica** o **distancia**, que asigna a cada par de puntos $ x, y \in X $ un número real $ d(x, y) $, y satisface las siguientes propiedades:
#
# 1. **No negatividad**: $ d(x, y) \geq 0\ $para todos $ x, y \in X $ y $ d(x, y) = 0 $ si y solo si $ x = y $.
# 2. **Simetría**: $ d(x, y) = d(y, x) $ para todos $ x, y \in X\ $.
# 3. **Desigualdad triangular**: $ d(x, z) \leq d(x, y) + d(y, z) $ para todos $ x, y, z \in X $.
#
# ### Ejemplos de Espacios Métricos
# 1. **Espacio Euclidiano**: $ X = \mathbb{R}^n $ y
#
#     $$d(x, y) = \sqrt{\sum_{i=1}^n (x_i - y_i)^2}.$$
#
# 2. **Espacio Discreto**: $ X $ es cualquier conjunto y
#
#     $$d(x, y) = 1 \text{ si } x \ne y, \text{ y } d(x, y) = 0 \text{ si } x = y.$$
#
# ### Propiedades de Espacios Métricos
# - **Convergencia**: Una secuencia $ (x_n) $ en $ X $ converge a $ x \in X $ si para todo $ \epsilon > 0 $, existe un $ N \in \mathbb{N} $
#
#     $$d(x_n, x) < \epsilon \text{ para todo } n \geq N.$$
#
# - **Completitud**: Un espacio métrico $ X $ es completo si toda sucesión de Cauchy en $ X $ converge a un punto en $ X $. Una sucesión $ (x_n) $ es de Cauchy si para todo $ \epsilon > 0 $, existe un $ N \in \mathbb{N} $ tal que $ d(x_n, x_m) < \epsilon $ para todo $ n, m \geq N $.

# %% [markdown]
# ### 🧿***Conjuntos Abiertos***
#
# #### *Definición de Conjunto Abierto*
# Un subconjunto $ U \subset X $ de un espacio métrico $ (X, d) $ es **abierto** si para todo $ x \in U $, existe un $ \epsilon > 0 $ tal que la bola abierta $ B(x, \epsilon) = \{ y \in X : d(x, y) < \epsilon \} $ está contenida en $ U $.
#
#
# ### Propiedades de los Conjuntos Abiertos
# - **Unión de Conjuntos Abiertos**: La unión arbitraria de conjuntos abiertos es un conjunto abierto.
# - **Intersección de Conjuntos Abiertos**: La intersección finita de conjuntos abiertos es un conjunto abierto.
# - **Espacios Métricos y Topología**: La colección de todos los conjuntos abiertos en un espacio métrico $ X $ forma una topología sobre  $ X $ , llamada la **topología métrica**.
#
# ### Ejemplos de Conjuntos Abiertos
# 1. En el espacio euclidiano $ \mathbb{R}^n $, cualquier bola abierta $ B(x, \epsilon) $ es un conjunto abierto.
# 2. En el espacio discreto, cada subconjunto es abierto.

# %% [markdown]
# ### 🎫***Relación entre Espacios Métricos y Conjuntos Abiertos***
#
# Bolas Abiertas y Cerradas
# - Una **bola abierta** de radio $ \epsilon $ centrada en $ x \in X $ se denota por $ B(x, \epsilon) $ y se define como $ B(x, \epsilon) = \{ y \in X : d(x, y) < \epsilon \} $.
#
# - Una **bola cerrada** de radio $ \epsilon $ centrada en $ x \in X $ se denota por $ \overline{B}(x, \epsilon) $ y se define como $ \overline{B}(x, \epsilon) = \{ y \in X : d(x, y) \leq \epsilon \} $.
#
#
# ### Conjuntos Cerrados
# Un subconjunto $ A \subset X $ es **cerrado** si su complemento $ X \setminus A $ es abierto. En un espacio métrico, los conjuntos cerrados pueden caracterizarse como aquellos que contienen todos sus puntos de acumulación.
#
# ### Frontera de un Conjunto
# La **frontera** de un conjunto $ A \subset X $, denotada $ \partial A $, es el conjunto de puntos que están en el cierre de $ A $ pero no en el interior de $ A $.

# %% [markdown]
# ### ✍️***Ejemplos y Aplicaciones***

# %% [markdown]
# #### 🕳️**Ejemplo 1:** Verificación de Conjuntos Abiertos en Python
# En este ejemplo, implementaremos una función en Python que verifica si un conjunto dado en un espacio métrico es abierto o no, utilizando la métrica estándar en el espacio euclidiano de los Reales.

# %%
import numpy as np

def es_conjunto_abierto(X, U, epsilon=1e-6):
    """
    Verifica si el conjunto U es abierto en el espacio métrico X.

    Args:
    - X: Conjunto de puntos en el espacio métrico (aquí se asume el espacio euclidiano R^n).
    - U: Conjunto que se quiere verificar si es abierto.
    - epsilon: Tolerancia para la verificación de la métrica (default: 1e-6).

    Returns:
    - True si U es abierto, False si no lo es.
    """
    for u in U:
        abierto = False
        for x in X:
            if np.linalg.norm(u - x) < epsilon:
                abierto = True
                break
        if not abierto:
            return False
    return True

# Ejemplo de uso
X = np.array([[0, 0], [1, 1], [2, 2], [3, 3]])  # Espacio métrico R^2
U1 = np.array([[0.5, 0.5], [1.5, 1.5]])  # Conjunto cerrado
U2 = np.array([[1, 1], [2, 2]])  # Conjunto abierto

print("¿U1 es abierto?", es_conjunto_abierto(X, U1))  # False
print("¿U2 es abierto?", es_conjunto_abierto(X, U2))  # True
# Out:
# ¿U1 es abierto? False
# ¿U2 es abierto? True

# %% [markdown]
# #### 🕳️**Ejemplo 2:** Visualización de Conjuntos Abiertos en un Espacio Métrico
# En este ejemplo, vamos a visualizar gráficamente conjuntos abiertos en un espacio métrico utilizando la biblioteca matplotlib en Python.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

def visualizar_conjunto_abierto(X, U, epsilon=0.5):
    """
    Visualiza un conjunto abierto U en el espacio métrico X (R^2).

    Args:
    - X: Conjunto de puntos en el espacio métrico (aquí se asume el espacio euclidiano R^2).
    - U: Conjunto abierto que se desea visualizar.
    - epsilon: Radio para dibujar las bolas abiertas (default: 0.5).
    """
    fig, ax = plt.subplots()

    # Dibujar todos los puntos en X
    ax.scatter(X[:, 0], X[:, 1], color='blue', label='Espacio métrico X')

    # Dibujar el conjunto U
    for u in U:
        circle = Circle(u, epsilon, color='green', alpha=0.2)
        ax.add_patch(circle)

    ax.set_aspect('equal')
    ax.set_title('Visualización de Conjunto Abierto en Espacio Métrico')
    ax.legend()
    plt.xlabel('Coordenada X')
    plt.ylabel('Coordenada Y')
    plt.grid(True)
    plt.show()

# Ejemplo de uso
X = np.array([[0, 0], [1, 1], [2, 2], [3, 3]])  # Espacio métrico R^2
U = np.array([[1, 1], [2, 2]])  # Conjunto abierto

visualizar_conjunto_abierto(X, U)

# %% [markdown]
# #### 🕳️**Aplicación:** Clustering con Conjuntos Abiertos
# En esta aplicación, utilizaremos la idea de conjuntos abiertos para realizar clustering en un conjunto de datos. Utilizaremos la distancia euclidiana como la métrica para definir la cercanía entre puntos.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generar datos aleatorios
X, _ = make_blobs(n_samples=300, centers=4, random_state=42)

# Aplicar K-means para clustering
kmeans = KMeans(n_clusters=4, random_state=42)
y_pred = kmeans.fit_predict(X)

# Visualización de los resultados
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='viridis')
plt.title('Clustering con K-means')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### 🧾Conclusión
#
# Los conceptos de espacio métrico y conjunto abierto son esenciales en el análisis matemático, proporcionando una base para entender la estructura y propiedades de diversos tipos de espacios. Estos conceptos permiten desarrollar teorías robustas y aplicaciones prácticas en múltiples áreas de la matemática.

# %% [markdown]
# ## 📓**Miro: Apuntes de la Clase**

# %% [markdown]
# Sea $E$ un conjunto
#
# $E \times E = \{ (x, y) : x \in E, y \in E \}$
#
# $E \times E \rightarrow \mathbb{R^+}$
#
# $d: (x, y) \rightarrow d(x, y)$
#
# $\begin{align*}
# 1) d(x, y) &= 0 \iff x = y \\
# 2) d(x, y) &= d(y, x) \\
# 3) d(x, z) &\leq d(x, y) + d(y, z)
# \end{align*}
# \forall x, y, z \in E$
#
# Sea $r > 0  $
#
# $B(o, r) = \{x \in E : d(x, o) \leq r\}$
#
# Ejemplo 1
#
# Sea \$ E = \mathbb{R}^2 \$
#
# $d(o, P) = \sqrt{(x - o)^2 + (y - o)^2}$
#
# $B(o,r) = \{ P \in \mathbb{R}^2 : \sqrt{x + y^2 } \leq r \} $
#
# $P = (x, y)$

# %% [markdown]
# Ejemplo 2
#
# Sea $E= \mathbb{R}^3 $
#
# $S (o, r)$
#
# $B(o,r) = \{ x \in \mathbb{R}^3 : \sqrt{x^2 + y^2 + z^2 } \leq, =, <   r \} $
#
# $(0, 0, 0)$

# %% [markdown]
# Ejemplo 3
#
# Sea $E = \mathbb R |x-o| $
#
# $B(o, r)= \{x \in \mathbb R: d(x, o) ≤r \}  $
#
# $\{x \in \mathbb R: |x- o| ≤r \}  $
#
# $\{x \in \mathbb R: o-r ≤x ≤ o+r \}  $
#
# $B(o, r)= [o-r, o+r ]  $
#
# $B_a(o, r)= ]o−r,o+r[ $
#
# $S(o, r)= B(o, r) ≠ B_a (o, r)= S(o, r)= \{x \in E: d(x, o)=r$
#
# $=\ [o-r, o+r] ≠ ]o-r, o+r[$
#
# $ =\{o-r, o+r \} $
#
#
# $2, 3$
#
# $2≤3$

# %% [markdown]
# Definicion: Sea $E$, conjunto y $d$ una distancia soobre $E$
#
# $(E, d)$ espacio metrico

# %% [markdown]
# ---
# # $$ \text{🎯 Preguntas} $$

# %% [markdown]
# **1.	¿Qué es la función distancia?**
#
# a)	Una función que mide el área entre dos puntos o espacio métrico
#
# b)	Una función que mide la distancia entre dos puntos o espacio métrico
#
# c)	Una función que mide el volumen entre dos puntos o espacio métrico
#
# d)	Una función que mide la curvatura entre dos puntos o espacio métrico
#
# e) Una función que mide el tiempo entre dos puntos o espacio métrico
#
# *Respuesta correcta: b*
#
# ***Explicación:*** La función distancia, o métrica, es una función que define cómo medir la distancia entre dos puntos en un espacio métrico. Esto es fundamental para definir la estructura del espacio métrico.
#
# **2.	¿Qué define una bola abierta en un espacio métrico?**
#
# a)	El centro y el diámetro.
#
# b)	El centro y el perímetro.
#
# c)	El centro y el radio.
#
# d)	El centro y la altura.
#
# e) El centro y el volumen
#
# *Respuesta correcta: c*
#
# ***Explicación:*** Una bola abierta en un espacio métrico es el conjunto de todos los puntos que están a una distancia menor que un cierto radio (r) desde un punto central (x). Esto se denota como
# 𝐵 (𝑥, 𝑟).
#
# **3.	¿Cuál es una característica de un conjunto abierto en un espacio métrico?**
#
# a)	Contiene su frontera.
#
# b)	Es siempre finito.
#
# c)	Para cualquier punto dentro del conjunto, existe una bola abierta contenida en el conjunto.
#
# d)	Es siempre cerrado.
#
# e) Contiene todos sus puntos límite
#
# *Respuesta correcta: c*
#
# ***Explicación:*** Un conjunto abierto es aquel donde, para cada punto dentro del conjunto, existe una bola abierta centrada en ese punto que también está completamente contenida en el conjunto. Esto garantiza que no se incluye la frontera del conjunto en sí mismo.
#
# **4.	¿Qué es un conjunto cerrado en un espacio métrico?**
#
# a)	Un conjunto que contiene todos sus puntos límite.
#
# b)	Un conjunto que no tiene puntos límite.
#
# c)	Un conjunto que contiene su complemento.
#
# d)	Un conjunto que es finito.
#
# e) Un conjunto que es abierto
#
# *Respuesta correcta: a*
#
# ***Explicación:*** Un conjunto cerrado incluye todos sus puntos límite. Es decir, cualquier punto que pueda aproximarse a partir de puntos dentro del conjunto también está contenido en el conjunto.
#
# **5.	¿Cómo se define el conjunto de adherencia de un conjunto 𝐴?**
#
# a)	La unión de 𝐴 con todos sus puntos límite.
#
# b)	La intersección de 𝐴 con todos sus puntos límite.
#
# c)	El complemento de 𝐴.
#
# d)	La diferencia entre y su frontera.
#
# e) La unión de 𝐴 con todos sus puntos interiores
#
# *Respuesta correcta: a*
#
# ***Explicación:*** La adherencia de un conjunto 𝐴 incluye todos los puntos de 𝐴 más todos los puntos límite de 𝐴. Los puntos límite son aquellos donde cualquier bola abierta centrada en ellos contiene al menos un punto de 𝐴.
#
# **6.	¿Cómo se denota una bola abierta?**
#
# a)	𝑆 (𝑥, 𝑟)
#
# b)	𝐶 (𝑥, 𝑟)
#
# c)	𝐵 (𝑥, 𝑟)
#
# d)	𝐷 (𝑥, 𝑟)
#
# e)  𝑅 (𝑥, 𝑟)
#
# *Respuesta correcta: c*
#
# Explicación: En notación estándar, una bola abierta centrada en
# 𝑥 con radio 𝑟 se denota como 𝐵 (
# 𝑥
# ,
# 𝑟
# )
# B(x,r).
#
# **7.	¿Cuáles son las propiedades que debe cumplir una métrica?**
#
# a)	Simetría y transitividad
#
# b)	Identidad, simetría y desigualdad triangular
#
# c)	No negatividad, simetría y desigualdad triangular
#
# d)	No negatividad, identidad, simetría y desigualdad triangular
#
# e) No negatividad, identidad y transitividad
#
# *Respuesta correcta: d*

# %% [markdown]
# **8. Dada la expresión:**
#
# ![image.png](data:image/png;base64,...)
#
# Determine sus límites cuando $x=1$:
#
# a) $\lim_{x \to 1^-} f(x) = 3 \quad \lim_{x \to 1^+} f(x) = 3$
#
# b) $\lim_{x \to 1^-} f(x) = 4 \quad \lim_{x \to 1^+} f(x) = 4$
#
# c) $\lim_{x \to 1^-} f(x) = 3 \quad \lim_{x \to 1^+} f(x) = 4$
#
# d) $\lim_{x \to 1^-} f(x) = 4 \quad \lim_{x \to 1^+} f(x) = 3$
#
# e) $\lim_{x \to 1^-} f(x) = 1 \quad \lim_{x \to 1^+} f(x) = 4$
#
# *Respuesta correcta: c)*
#
# **Explicación:**
# Analizando el límite por la izquierda (valores menores a 1) se debe tomar la primera ecuación, dándonos como resultado $3$.
#
# Analizando el límite por la derecha (valores mayores a 1) se debe tomar la segunda ecuación, dándonos como resultado $4$.

# %% [markdown]
# **9. Encuentra el valor de $ c $ que hace continua la función** $ f(x) = \begin{cases}
# 3x + 1 & \text{si } x \leq 2 \\
# cx^2 + 2 & \text{si } x > 2
# \end{cases} $
# en $ x = 2 $.
#
# a) $ c = 1 $
# b) $ c = \frac{5}{4} $
# c) $ c = 3 $
# d) $ c = 4 $
# e) $ c = 2 $
#
# *Respuesta correcta: b)*
#
# **Explicación:** Para que la función sea continua en $ x = 2 $, debemos tener:
#
# $ \lim_{x \to 2^-} f(x) = \lim_{x \to 2^+} f(x) = f(2) $
#
# Calculamos el límite izquierdo:
#
# $ \lim_{x \to 2^-} f(x) = \lim_{x \to 2^-} (3x + 1) = 7 $
#
# Calculamos el límite derecho:
#
# $ \lim_{x \to 2^+} f(x) = \lim_{x \to 2^+} (cx^2 + 2) = 4c + 2 $
#
# Para que estos límites sean iguales, igualamos:
#
# $ 7 = 4c + 2 $
#
# $ 5 = 4c $
#
# $ c = \frac{5}{4} $
#
# **10. Determina los puntos de discontinuidad de la función** $ f(x) = \frac{x^2 - 4}{x - 2} $.
#
# a) $ x = 2 $
# b) $ x = -2 $
# c) $ x = 0 $
# d) $ x = 4 $
# e) Ninguno
#
# *Respuesta correcta: a)*
#
# **Explicación:** Para encontrar los puntos de discontinuidad, debemos identificar los valores de $ x $ para los cuales la función no está definida.
#
# $ f(x) = \frac{x^2 - 4}{x - 2} = \frac{(x - 2)(x + 2)}{x - 2} $
#
# La función está definida para todos los valores de $ x $ excepto donde el denominador es cero, es decir, cuando $ x = 2 $. Por lo tanto, $ x = 2 $ es un punto de discontinuidad.
#
# **11. Dada la función** $ f(x) = \begin{cases}
# \sin(x) & \text{si } x \leq 0 \\
# x^2 & \text{si } x > 0
# \end{cases} $,
# **verifica si la función es continua en $ x = 0 $ usando límites laterales.**
#
# a) Sí, porque $ \lim_{x \to 0^-} \sin(x) = 0 $ y $ \lim_{x \to 0^+} x^2 = 0 $.
# b) No, porque $ \lim_{x \to 0^-} \sin(x) = 1 $ y $ \lim_{x \to 0^+} x^2 = 0 $.
# c) Sí, porque $ f(0) = 0 $.
# d) No, porque $ \lim_{x \to 0} \sin(x) \neq 0 $.
# e) Sí, porque $ \sin(x) $ y $ x^2 $ son continuas en $ x = 0 $.
#
# *Respuesta correcta: a)*
#
# **Explicación:** Calculamos los límites laterales y comparamos con $ f(0) $:
#
# $ \lim_{x \to 0^-} \sin(x) = \sin(0) = 0 $
#
# $ \lim_{x \to 0^+} x^2 = 0^2 = 0 $
#
# $ f(0) = \sin(0) = 0 $
#
# Como ambos límites laterales son iguales y coinciden con el valor de la función en $ x = 0 $, la función es continua en $ x = 0 $.
#
# **12. Sea la función** $ f(x) = \begin{cases}
# 2x + 1 & \text{si } x < 1 \\
# k & \text{si } x = 1 \\
# 3x - 1 & \text{si } x > 1
# \end{cases} $.
# **Encuentra el valor de $ k $ que hace continua la función en $ x = 1 $.**
#
# a) $ k = 1 $
# b) $ k = 2 $
# c) $ k = 3 $
# d) $ k = 4 $
# e) $ k = 5 $
#
# *Respuesta correcta: c)*
#
# **Explicación:** Para que la función sea continua en $ x = 1 $, debemos tener:
#
# $ \lim_{x \to 1^-} f(x) = \lim_{x \to 1^+} f(x) = f(1) $
#
# Calculamos los límites laterales y los igualamos a $ k $:
#
# $ \lim_{x \to 1^-} (2x + 1) = 2(1) + 1 = 3 $
#
# $ \lim_{x \to 1^+} (3x - 1) = 3(1) - 1 = 2 $
#
# El valor de $ k $ debe ser igual a 3 para que la función sea continua en $ x = 1 $.
#
# **13. Sea la función** $ f(x) = \begin{cases}
# \frac{\sin(x)}{x} & \text{si } x \neq 0 \\
# 1 & \text{si } x = 0
# \end{cases} $.
# **Comprueba si la función es continua en $ x = 0 $.**
#
# a) Sí, porque $ \lim_{x \to 0} \frac{\sin(x)}{x} = 1 $.
# b) No, porque $ \lim_{x \to 0} \frac{\sin(x)}{x} \neq 1 $.
# c) No, porque $ \frac{\sin(x)}{x} $ no está definida en $ x = 0 $.
# d) Sí, porque $ \sin(x) $ es continua.
# e) No, porque $ f(0) = 0 $.
#
# *Respuesta correcta: a)*
#
# **Explicación:** Calculamos el límite de $ f(x) $ cuando $ x $ tiende a 0:
#
# $ \lim_{x \to 0} \frac{\sin(x)}{x} = 1 $
#
# Y el valor de la función en $ x = 0 $:
#
# $ f(0) = 1 $
#
# Como el límite cuando $ x $ tiende a 0 es igual al valor de la función en $ x = 0 $, la función es continua en $ x = 0 $.
#
# 14. **Considera la función:**
#
# $ f(x) = \begin{cases}
# \sin(x) & \text{si } x \leq 0 \\
# x^2 & \text{si } x > 0
# \end{cases} $
#
# **Determina si la función es continua en todos los puntos.**
#
# a) Sí, porque $ \lim_{x \to 0^-} \sin(x) = 0 $ y $ \lim_{x \to 0^+} x^2 = 0 $.
# b) No, porque $ \lim_{x \to 0^-} \sin(x) = 1 $ y $ \lim_{x \to 0^+} x^2 = 0 $.
# c) Sí, porque $ f(0) = 0 $.
# d) No, porque $ \lim_{x \to 0} \sin(x) \neq 0 $.
# e) Sí, porque $ \sin(x) $ y $ x^2 $ son continuas en $ x = 0 $.
#
# *Respuesta correcta: a)*
#
# **Explicación:** Para verificar la continuidad en todos los puntos, calculamos los límites laterales y comparamos con el valor de la función en $ x = 0 $.
#
# 1. **En $ x = 0 $**:
#    $$
#    \lim_{x \to 0^-} \sin(x) = \sin(0) = 0
#    $$
#    $$
#    \lim_{x \to 0^+} x^2 = 0^2 = 0
#    $$
#    $$
#    f(0) = \sin(0) = 0
#    $$
#    Como ambos límites laterales son iguales y coinciden con el valor de la función en $ x = 0 $, la función es continua en $ x = 0 $.

# %% [markdown]
# # $$ \text{👨‍💻 Referencias y Licencias} $$

# %% [markdown]
# Este trabajo utiliza material del curso "Matemáticas y Programación para Ciencias Sociales" de FLACSO Ecuador.
#
# Pérez, F. (2024). Matemáticas y Programación para Ciencias Sociales. FLACSO Ecuador.
#
#
# - Repositorio GitHub: https://github.com/franperezec/math (Licencia MIT)
#
#
#
#
# - Canal de YouTube: https://www.youtube.com/@FranciscoPerezMatematicas (CC BY 4.0)
#
#
# Al utilizar este material, acepto cumplir con los términos de las licencias MIT y Creative Commons BY 4.0 respectivamente.
#
# Para más detalles sobre las licencias o usos adicionales, consultar:
#
#
# - Licencia MIT: https://opensource.org/licenses/MIT
#
#
#
#
# - CC BY 4.0: https://creativecommons.org/licenses/by/4.0/deed.es
