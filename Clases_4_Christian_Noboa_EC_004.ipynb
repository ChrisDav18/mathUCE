# %% [markdown]
# <a href="https://colab.research.google.com/github/ChrisDav18/mathUCE/blob/main/Clases_4_Christian_Noboa_EC_004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Funciones Matemáticas: Imagen y Preimagen ✏️
# #Funciones➗
#
# La función debe tener 2 conjuntos, sea $A$, $B$ cojuntos. Esto se entiende como una **regla de asociación**.
#
# Una función $f$ de A o B es una regla de asociación que a cada elemento $xϵA$, le asocia un único elemento $yϵB$, al que se lo denomina **imagen de x** a través de $f$ y se lo denota como $y=f(x)$
#
# $f: A$->$B$
#   $x$-> $y=f(x)$
#
# Esta mal plantear $f(x)=3x^2$ 😕 debido a que no es una función en si, sino solo la regla de asociación, entonces debemos completarlo: $f: R$->$R$ , $x$->$f(x)=3x^2$
#
# #Elementos 🔍
# **Las funciones tienen 4 elementos:**
# - **Nombre para identificarla**🏷️
# - **Espacio de partida** 🌌
# - **Espacio de llegada** 🎯
# - **Regla de asociación** 🔗
#
# Nota: Existen funciones numéricas pero también pueden ser no numéricas. Por ejemplo: $A=${palabras del castellano}, $B=${a,b,...z}, entonces podemos crear la función $I:A->B$, $x$->$f(x)=$letra inicial de cada palabra, entonces $I$(marsupial)=m
#
# **Ejemplos interesantes de funciones** 🔢
#
# $R*R$={$(x,y): xϵR,yϵR$}
# - **Suma**$+$: $R*R$ ->$R, (x,y)$->$+(x,y)=x+y$
# - **Multiplicación** $*$: $R^2$->$R, (x,y)$-> $x(x,y)=xy$
# - **Relación de orden** $R≤$:  $R^2$ -> {$0,1$}, $(x,y)$-> $R≤(x,y)$. Si $=1$ si $x≤y$, Si $= 0$ si no. Con ello podemos decir si la relación se cumple o no se cumple.
#
# #Secuencia 📊
#
# La secuencia se refiere a un tipo particular de función que parte de los números $N$.
#
# Ejemplo:
# - **$R^N=${$(xi)iϵN: ∀iϵN, xiϵR$} en este conjunto , tenemos un conjunto numerable con secuencia de números pares, es decir, $P: N^*->N^*, n$->$P(n):2n$ y podemos partirlo en una secuencia como: x:$N$-> $R$, $n$->$x(n)=1/n^2+1$.
# Entonces si ponemos por ejemplo $Xo=1$, $x1$ sera $1/2$ y $x2$ sera $1/5$
#
# Nota: Es mejor tener una concepción mental de cada función:
# ![image.png](data:image/png;base64,...)
#
# Nos permite desarrollar los conceptos de **Imagen** y **Preimagen**
#
# #Imagen y Pre imagen  🔄
# Se aplican a conjuntos y nos arrojan conjuntos:
#
# **Imagen**:conjunto de números reales que son imagen por de los elementos de su dominio.
#
# **Preimagen:** Es un conjunto de puntos en $A$ cuya imagen pertenece a ese conjunto.
#
# Supongamos que tenemos la función:
#
# $f: A$-> $B$, x-> $f(x)$
#
# - Sea $E⊆A$, $f(E)$:{$f(x)ϵB:xϵE$}, significa que $f(E)$ es un conjunto de las imagenes cuyos elemetos de $E$ existen en $B$, es decir la imagen de E.
# - Sea $F⊆B$, $f^-1(F):=${$xϵA:f(x)ϵF$}, esto seria la preimagen de F (osea que podemos usar la función inversa para encontrar la preimagen).
#
# Ejemplos:
#
# $f(A)⊆B$
#
# $f: R$->$R, X$ -> $f(x)=x^2+1$
#
# $f(R)$={$f(x)ϵR:xϵR$}, = {$x^2+1:xϵR$}
#
# $f(R)$={$xϵR: x≥1$} o $[1,+∞[⊆R$
#
# La preimagen seria: $f^-1(]-10,0[)$ y la definición seria: {$xϵR:x^2+1ϵ]-10,0[$}

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2 + 1

x = np.linspace(-10, 10, 400)

y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$f(x) = x^2 + 1$', color='blue')
plt.title('Gráfica de $f(x) = x^2 + 1$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.show()

# %% [markdown]
# #Ejercicios: 📝
#
# ¿Cuál seria la preimagen del conjunto $f^-1:([0,2])$?
#
# {$xϵR: x^2+1ϵ[0,2]$} Como buscamos la preimagen debemos analizarlo algebraicamente.
#
# = {$xϵR: 0≤x^2+1≤2$}
#
# = {$xϵR:-1≤x^2≤1$}  y buscamos que x son igual o menores a 1
#
# = {$xϵR:-1≤x≤1$} finalmente podemos decir que la preimagen de  $f^-1:([0,2])$ es $[-1,1]$
#
# Gráficamente se ve:

# %%
import numpy as np
import matplotlib.pyplot as plt

def f_inv(y):
    return np.sqrt(y - 1)

y = np.linspace(1, 2, 400)

x_positive = f_inv(y)
x_negative = -f_inv(y)

plt.figure(figsize=(8, 6))
plt.plot(x_positive, y, label=r'$f^{-1}(y) = \sqrt{y - 1}$', color='red')
plt.plot(x_negative, y, label=r'$f^{-1}(y) = -\sqrt{y - 1}$', color='blue')
plt.title('Gráfica de la función inversa $f^{-1}(y)$')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %% [markdown]
# Ejemplo:
#
# $g: R$ -> $R, x$->$g(x)=sin(x)$
#
# ¿Cuál es la imagen?
#
# $g(R)= [-1,1]$  todos los puntos de los reales tienen una imagen que pertenece al conjunto $[-1,1]$
#
# Según la definición:
#
# $g(R)$={$g(x)ϵR:xϵR$}
# ={$sin(x):xϵR$}
#
# = $[-1,1]$.
#
# La funcion de seno siempre tiene un conjunto del $[-1,1]$
#
# Gráficamente:

# %%
import numpy as np
import matplotlib.pyplot as plt

def g(x):
    return np.sin(x)

x = np.linspace(-2 * np.pi, 2 * np.pi, 400)

y = g(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$g(x) = \sin(x)$', color='purple')

plt.scatter([-np.pi/2, np.pi/2], [-1, 1], color='red', zorder=5)
plt.text(-np.pi/2, -1.1, '(-π/2, -1)', color='red', horizontalalignment='center')
plt.text(np.pi/2, 1.1, '(π/2, 1)', color='red', horizontalalignment='center')

plt.title('Gráfica de $g(x) = \sin(x)$')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ¿Cuál es la preimagen de $g^-1$({$2$})?
#
# Al aplicar la definición, nos damos cuenta que pertenece al conjunto vacio $∅$
#
#
#
#
# ¿Cuál es la preimagen de $g^-1([0,+∞[)$?
#
# Se lo puede definir como:
#
# $g^-1([0,+∞[)$ ={$xϵR:g(x)ϵ[0,+∞[$}, ahora me pregunto cuales son los x cuya imagen pernetencen a $[0,+∞[$. Entonces:
#
# ={$xϵR:sin(x)≥0$}
#
# Como sabemos el seno tiene un periodo de $0$ hasta $π$ pero debe estar completo:
#
# = {$xϵR:sinxϵ[0,π]$} v $xϵ[2π,3π]$ v $xϵ[4π,5π]$. Esto es como decir que estamos trabajando con la unión $∪$$nϵZ$$[2nπ,(2n+1)π]$.
#
# Nota: La imagen y la pre imagen siguen siendo la misma pero la respuesta siempre requiere una respuesta matemática cada vez más compleja dependiendo de la función.

# %% [markdown]
# # Conclusión 🙂:

# %%
from tabulate import tabulate

conceptos = [
    ["Preimagen", "La preimagen de un conjunto B en Y es el conjunto de todos los elementos en X que se mapean a ese conjunto específico B bajo la función f. La preimagen de un elemento b en Y se denota como f^{-1}(b)."],
    ["Imagen", "La imagen de un conjunto A bajo una función f es el conjunto de todos los valores que f puede tomar cuando A varía en X. Matemáticamente, se denota como f(A). También se puede expresar como { y ∈ Y | ∃ x ∈ A, f(x) = y }."]
]

print(tabulate(conceptos, headers=["Concepto", "Definición"], tablefmt="fancy_grid"))
# Out:
# ╒════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ Concepto   │ Definición                                                                                                                                                                                                                   │
# ╞════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ Preimagen  │ La preimagen de un conjunto B en Y es el conjunto de todos los elementos en X que se mapean a ese conjunto específico B bajo la función f. La preimagen de un elemento b en Y se denota como f^{-1}(b).                      │
# ...

# %% [markdown]
# ## Referencias y Licencias
#
# Este trabajo utiliza material del curso "Matemáticas y Programación para Ciencias Sociales" de FLACSO Ecuador.
#
# Pérez, F. (2024). Matemáticas y Programación para Ciencias Sociales. FLACSO Ecuador.
# - Repositorio GitHub: https://github.com/franperezec/math (Licencia MIT)
# - Canal de YouTube: https://www.youtube.com/@FranciscoPerezMatematicas (CC BY 4.0)
#
# Al utilizar este material, acepto cumplir con los términos de las licencias MIT y Creative Commons BY 4.0 respectivamente.
#
# Para más detalles sobre las licencias o usos adicionales, consultar:
# - Licencia MIT: https://opensource.org/licenses/MIT
# - CC BY 4.0: https://creativecommons.org/licenses/by/4.0/deed.es
