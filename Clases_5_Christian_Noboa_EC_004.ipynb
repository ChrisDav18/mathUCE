# %% [markdown]
# <a href="https://colab.research.google.com/github/ChrisDav18/mathUCE/blob/main/Clases_5_Christian_Noboa_EC_004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones: Utilidad, Tipos y Composición

# %% [markdown]
# ## Recordemos:
# Las forma especifica para una función:
# - Le damos un nombre $f:$📝
# - Regla de asociación que debe recorrer desde un espacio de partida a un espacio de llegada. $Ω$->$B, x$->$f(x)$
#
# Nota: la imagen y pre imagen se aplica a los conjuntos

# %%
from tabulate import tabulate

conceptos = [
    ["Preimagen", "La preimagen de un conjunto B en Y es el conjunto de todos los elementos en X que se mapean a ese conjunto específico B bajo la función f. La preimagen de un elemento b en Y se denota como f^{-1}(b)."],
    ["Imagen", "La imagen de un conjunto A bajo una función f es el conjunto de todos los valores que f puede tomar cuando A varía en X. Matemáticamente, se denota como f(A). También se puede expresar como { y ∈ Y | ∃ x ∈ A, f(x) = y }."]
]

print(tabulate(conceptos, headers=["Concepto", "Definición"], tablefmt="fancy_grid"))
# Out:
# ╒════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ Concepto   │ Definición                                                                                                                                                                                                                   │
# ╞════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ Preimagen  │ La preimagen de un conjunto B en Y es el conjunto de todos los elementos en X que se mapean a ese conjunto específico B bajo la función f. La preimagen de un elemento b en Y se denota como f^{-1}(b).                      │
# ...

# %% [markdown]
# # Función de utilidad en Economía 📈
# En economía, una función de utilidad es una herramienta utilizada para expresar el nivel de satisfacción o bienestar que una persona obtiene al consumir bienes. Esta función calcula la utilidad o satisfacción obtenida a partir de la cantidad de bienes consumidos.
# - **Función de Utilidad con un solo Bien**
#
# Pensemos que solo tenemos diponible el bien del agua💧, la función de utilidad se le puede representar como (u(x)), (x) es la cantidad de agua que se consumio y (u(x)) es la utilidad que se obtiene. Se lo puede denotar como: $[Agua(x)$-> $Utilidad(u(x))]$

# %%
import matplotlib.pyplot as plt
import numpy as np

def utilidad_agua(x):
    return np.sqrt(x)

x = np.linspace(0, 10, 100)
y = utilidad_agua(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='Utilidad de Consumo de Agua')
plt.xlabel('Cantidad de Agua (Litros)')
plt.ylabel('Utilidad')
plt.title('Función de Utilidad para Consumo de Agua')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Podemos visualizar esta conexión usando una curva que ilustra cómo la utilidad crece al incrementar el consumo de agua. No obstante, la utilidad marginal disminuye gradualmente, lo que indica que cada adición de agua proporciona menos satisfacción que la anterior. Por ejemplo, el primer vaso de agua puede ofrecer mucho placer en un día caluroso, pero los vasos adicionales, como el tercero o cuarto, proporcionan menos satisfacción en comparación.

# %% [markdown]
# - Función de Utilidad con dos bienes 📈
#
# Pongamos en situación en que no solo tenemos ahora agua💧 sino que tambien tenemos pan🥖, Esta función de utilidad ahora dependera de la cantidad consumida de ambas, es decir, $[u(x,y)]$
#
# $x$ representa la cantidad de agua e $y$ la cantidad de pan. La utilidad se representa en un gráfico tridimensional, donde los ejes $x$ e $y$ corresponden a las cantidades de los dos bienes, y el eje vertical representa la utilidad. Esta representación gráfica muestra una superficie de utilidad.
#
# Podemos imaginar esta superficie como una forma de concha, donde cada punto en la superficie representa un nivel específico de utilidad asociado con una combinación particular de $x$ e $y$. Si observamos desde el plano $xy$, veremos curvas parecidas a las del caso unidimensional.
#
# Ejemplos:
# - (log(x))
# -(√x)
#
# Graficamente:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 400)

y = np.log(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='log(x)', color='b', linewidth=2)

plt.title('Gráfica de log(x)')
plt.xlabel('x')
plt.ylabel('log(x)')
plt.grid(True)
plt.legend()

plt.show()

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 400)

y = np.sqrt(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='sqrt(x)', color='g', linewidth=2)

plt.title('Gráfica de sqrt(x)')
plt.xlabel('x')
plt.ylabel('sqrt(x)')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Estas funciones son crecientes pero cada vez tienen una pendiente menor, lo que muestra es el **principio de utilidad marginal decreciente**.

# %% [markdown]
# #Notación Matemática de la Función de Utilidad 📊
# - Definición de la función de utilidad: [$U:R+^2$->$R+]$, Significa que la función de utilidad $U$ toma como entrada a un par de números reales o negativos $((R+^2))$ y se produce un número real no negativo $((R+))$.
#
# - Expresión de la función de utilidad: $[(x,y)$->$u(x,y)]$, Significa que $((x,y))$ son las cantidades de los 2 bienes y el nivel de utilidad de esas cantidades es: $(u(x.y))$
# - Conjuntos de Nivel: $[${$(x,y)∈R+^2:u(x,y)=10$}] , significa que $((x,y))$ son el conjunto de todos los pares en $(R^2)$ y dan una utilidad de 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

def u(x, y):
    return np.log(x) + np.sqrt(y)

x = np.linspace(0.1, 5, 400)
y = np.linspace(0, 10, 400)
X, Y = np.meshgrid(x, y)
Z = u(X, Y)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='plasma', edgecolor='none', alpha=0.8)

contours = ax.contour(X, Y, Z, levels=[1, 2, 3, 4, 5, 10], cmap='inferno', linestyles="solid")

ax.set_xlabel('Bien 1')
ax.set_ylabel('Bien 2')
ax.set_zlabel('Utilidad U(x, y)')
ax.set_title('Función de Utilidad y Conjuntos de Nivel')

plt.show()

# %% [markdown]
# Estos conjuntos de nivel se los representa por curvas de nivel conocidos como $(isocuantas)$

# %% [markdown]
# #Notación Matemática📊
# - Conjunto de nivel:
#
# [$f^-1$({$10$})={$(x,y)∈R^2:u(x,y)∈${$10$}}]
#
# [{$(x,y):√xy=10$}], al simplicarlo queda: [{$(x,y):xy=100$}]
#
# - Generalización para un nivel de utilidad:
# [$f^-1$({$u0$})={$(x,y)∈R+^2:y=uo^2/x$}], significa que para un nivel de utilidad $(u0)$, se mantienne la relación $(x)$ e $(y)$ en la ecuación de antes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def u(x, y):
    return np.sqrt(x * y)

x = np.linspace(0.1, 10, 400)
y = np.linspace(0.1, 10, 400)
X, Y = np.meshgrid(x, y)
Z = u(X, Y)

u_levels = [5, 10, 15, 20, 25]

fig = plt.figure(figsize=(14, 9))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='plasma', edgecolor='none', alpha=0.7)

colors = ['blue', 'green', 'red', 'purple', 'orange']
for i, u0 in enumerate(u_levels):
    x_contour = np.linspace(0.1, 10, 400)
    y_contour = (u0**2) / x_contour
    z_contour = u(x_contour, y_contour)
    ax.plot(x_contour, y_contour, z_contour, label=f'u0 = {u0}', linewidth=2, color=colors[i])

ax.set_xlabel('Bien 1')
ax.set_ylabel('Bien 2')
ax.set_zlabel('Utilidad U(x, y)')
ax.set_title('Superficie de la Función de Utilidad y Conjuntos de Nivel')

ax.legend()
plt.show()

import numpy as np
import matplotlib.pyplot as plt

def u(x, y):
    return np.sqrt(x * y)

def preimage(u0, x):
    return u0**2 / x

u_levels = [5, 10, 15, 20, 25]

x = np.linspace(0.1, 10, 400)

colors = ['blue', 'green', 'red', 'purple', 'orange']

plt.figure(figsize=(10, 6))

for i, u0 in enumerate(u_levels):
    y = preimage(u0, x)
    plt.plot(x, y, label=f'u0 = {u0}', color=colors[i])

plt.xlabel('Bien 1')
plt.ylabel('Bien 2')
plt.title('Conjuntos de Nivel de la Función de Utilidad')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# #Función Sobreyectiva, Biyectiva, Inyectiva, Inversa y Compuesta 🔄

# %% [markdown]
# - **Función sobreyectiva** 🎯
#
# Es sobreyectiva cuando su imagen cubre todo el conjunto $(B):[f(A)=B]$, lo que significa que $(y∈B)$ tiene que existir al menos $(x∈A)$ lo que daria como resultado: $[f(x)=y]$

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2

x = np.linspace(-5, 5, 100)
y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x^2', color='blue')
plt.title('Gráfica de una Función Sobreyectiva')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# %% [markdown]
# - **Función Inyectiva**🔍
#
# Es inyectiva cuando se le asigna elementos distintos de (A) a los elementos distintos de (B), es decir: $[∀x,x'∈A, x≠x'$ -> $f(x)≠f(x')]$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de la función inyectiva
def f(x):
    return x

# Rango de valores para x
x = np.linspace(-5, 5, 100)
y = f(x)

# Creación del gráfico
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x', color='blue')
plt.title('Gráfica de una Función Inyectiva')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# %% [markdown]
# - **Función Biyectiva**🔗
#
# Es biyectiva cuando es tanto **Inyectiva** como **Sobreyectiva**. Denotado como: $[f $es biyectiva$⇔f $$es inyectiva ∧ f es sobreyectiva$]

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3

x = np.linspace(-2, 2, 100)
y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x^3', color='blue')
plt.title('Función Biyectiva f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.show()

# %% [markdown]
# - **Función inversa** 🔁
#
# Toda función biyectiva tiene su función inversa $(f^-1)$ y va desde $(B)$ hasta $(A)$.
#
# Se denota como: $(f^-1)$
#
#  Función inversa (g) cumple con: $[g:B$ ->$A][g(y)=x  $tal que $ f(x)=y]$
#
# Tiene que cumplir 2 propiedades:
# - [∀x∈A, g(f(x))=x]
# - [∀x∈B, f(g(y))=y]

# %% [markdown]
# #Funciones Compuestas🔀
# **Definición**📜
# - Partimos de 3 conjuntos: $E$,$F$ y $G$
# - Definimos 2 funciones: (f) y (g):
#
# $(f:E$->$F)$, donde $(f(x)=f(x))$
#
# $(g: F$ -> $G)$, donde $(g(y)=g(y))$
#
# **La función compuesta** $(g $ o $f)$ es definidad con la notación: $[(g$ o $f)(x))=g(f(x))]$, lo que significa que se toma un elemento $x$ de $E$, se le aplica la función $f$ para tener  $(f(x))$ en $F$, despues aplicar la función $g$ a $(f(x))$ para obtener $(g(f(x)))$ en $(G)$.
#
# **Definición de Funciones📊:**
#
# -Función $(f)$ de los reales a un intervalo: $[f:R$->$[1,+∞[]$ $[f(x)=x^2+1]$
#
# -Función $(g)$ del intervalo $([1,+∞])$ a los reales positivos: $[g:[1,+∞[$-> $R^+] [g(y)=√y]$
#
# **Composición de $(g)$y$(f)$🔄:**
#
# Se la define como: $[g o f: R$-> $R^+]$= $[(g/circf)(x)$
#
# $=g(f(x))=g(x^2+1) = √x^2+1] rt{x^2+1}$
#
#
# **Ejemplo de Función compuesta🌟:**
#
# $(h(x)):[h(x)=√x^2+1]$

# %%
import numpy as np
import matplotlib.pyplot as plt

def h(x):
    return np.sqrt(x**2 + 1)

x = np.linspace(-5, 5, 400)
y = h(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='h(x) = sqrt(x^2 + 1)', color='blue')
plt.title('Gráfica de la función h(x)=g(f(x))')
plt.xlabel('x')
plt.ylabel('h(x)')
plt.legend()
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.show()
